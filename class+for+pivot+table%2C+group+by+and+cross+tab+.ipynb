# %%
import pandas as pd

# %%
adult=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
adult
# Out:
#        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %%
adult.head
# Out:
# <bound method NDFrame.head of        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %%
adult.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
# Out:
#   File "<ipython-input-34-37f3570b4a5a>", line 1
#     adult.columns=[‘age’, ‘workclass', ‘fnlwgt’, ‘education’, ‘education-num’, ‘marital-status’, ‘occupation’, ‘relationship’, ‘race’, ’sex’, ‘capital-gain’, ‘capital-loss’, ‘hours-per-week’, ‘native-country’ ]
#                        ^
# SyntaxError: invalid character in identifier

# %%
 
adult.columns=['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-coutry', 'Income' ]

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week   native-coutry  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
adult1=pd.crosstab(adult.sex,adult.Income)

# %%
adult1
# Out:
# Income    <=50K   >50K
# sex
#  Female    9592   1179
#  Male     15125   6662

# %% [markdown]
# Male has more higher generation people

# %%
adult2=pd.crosstab(adult.race,adult.Income,margins=True).apply(lambda r:r/len(adult),axis=1)

# %%
# Out:
# Income                  <=50K      >50K       All
# race
#  Amer-Indian-Eskimo  0.008446  0.001106  0.009552
#  Asian-Pac-Islander  0.023434  0.008477  0.031910
#  Black               0.084060  0.011886  0.095946
#  Other               0.007555  0.000768  0.008323
#  White               0.635688  0.218581  0.854269

# %%
adult4=pd.groupby(adult.sex).adult.mean()

# %%
adult.groupby(['sex','education','marital-status']).age.max().reset_index()
# Out:
#          sex      education          marital-status  age
# 0     Female           10th                Divorced   74
# 1     Female           10th      Married-civ-spouse   81
# 2     Female           10th   Married-spouse-absent   53
# 3     Female           10th           Never-married   67
# 4     Female           10th               Separated   69
# 5     Female           10th                 Widowed   76
# 6     Female           11th                Divorced   72
# 7     Female           11th      Married-civ-spouse   60
# 8     Female           11th   Married-spouse-absent   60
# 9     Female           11th           Never-married   71
# 10    Female           11th               Separated   62
# 11    Female           11th                 Widowed   76
# 12    Female           12th                Divorced   58
# 13    Female           12th      Married-civ-spouse   61
# 14    Female           12th   Married-spouse-absent   47
# ...

# %%
adult1 = adult.set_index([ 'education','marital-status'])['Income'].unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-408ee37039b3> in <module>()
# ----> 1 adult1 = adult.set_index([ 'education','marital-status'])['Income'].unstack()
#
# c:\users\varavoorgp\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    2088         """
#    2089         from pandas.core.reshape import unstack
# -> 2090         return unstack(self, level, fill_value)
#    2091
#    2092     # ----------------------------------------------------------------------
#
# c:\users\varavoorgp\anaconda3\lib\site-packages\pandas\core\reshape.py in unstack(obj, level, fill_value)
#     411     else:
#     412         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 413                                fill_value=fill_value)
#     414         return unstacker.get_result()
#     415
#
# ...

# %%
adult1 = adult.pivot_table(index='education', columns='age', values='marital-status', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-112-4dc5d5129aca> in <module>()
# ----> 1 adult1 = adult.pivot_table(index='education', columns='age', values='marital-status', aggfunc='mean')
#
# c:\users\varavoorgp\anaconda3\lib\site-packages\pandas\tools\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     125
#     126     grouped = data.groupby(keys)
# --> 127     agged = grouped.agg(aggfunc)
#     128
#     129     table = agged
#
# c:\users\varavoorgp\anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3702     @Appender(SelectionMixin._agg_doc)
#    3703     def aggregate(self, arg, *args, **kwargs):
# -> 3704         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3705
#    3706     agg = aggregate
#
# ...

# %%
adult1.head()
# Out:
# age               17         18         19         20       21         22  \
# education
#  10th      21.543478  27.894737  34.500000  39.400000  39.0000  37.052632
#  11th      19.927778  22.066265  31.777778  37.074074  40.3125  39.761905
#  12th      20.189189  22.950000  28.862069  37.500000  31.8750  40.615385
#  1st-4th         NaN        NaN  49.000000  30.000000  40.0000  32.000000
#  5th-6th   48.000000  41.000000  43.000000  35.000000  40.0000  39.363636
#
# age               23         24         25         26  ...     80         81  \
# education                                              ...
#  10th      42.588235  41.888889  38.714286  42.705882  ...    NaN  28.000000
#  11th      41.217391  41.120000  41.269231  37.826087  ...   25.0        NaN
#  12th      36.533333  41.625000  41.181818  48.555556  ...    NaN        NaN
#  1st-4th   37.000000  41.500000  44.166667        NaN  ...    NaN  26.666667
# ...

# %%
adult2 = adult.groupby(['education', 'age'])['hours-per-week'].mean().unstack()

# %%
adult2.head()
# Out:
# age               17         18         19         20       21         22  \
# education
#  10th      21.543478  27.894737  34.500000  39.400000  39.0000  37.052632
#  11th      19.927778  22.066265  31.777778  37.074074  40.3125  39.761905
#  12th      20.189189  22.950000  28.862069  37.500000  31.8750  40.615385
#  1st-4th         NaN        NaN  49.000000  30.000000  40.0000  32.000000
#  5th-6th   48.000000  41.000000  43.000000  35.000000  40.0000  39.363636
#
# age               23         24         25         26  ...     80         81  \
# education                                              ...
#  10th      42.588235  41.888889  38.714286  42.705882  ...    NaN  28.000000
#  11th      41.217391  41.120000  41.269231  37.826087  ...   25.0        NaN
#  12th      36.533333  41.625000  41.181818  48.555556  ...    NaN        NaN
#  1st-4th   37.000000  41.500000  44.166667        NaN  ...    NaN  26.666667
# ...

# %%
adult2
# Out:
# age                   17         18         19         20         21  \
# education
#  10th          21.543478  27.894737  34.500000  39.400000  39.000000
#  11th          19.927778  22.066265  31.777778  37.074074  40.312500
#  12th          20.189189  22.950000  28.862069  37.500000  31.875000
#  1st-4th             NaN        NaN  49.000000  30.000000  40.000000
#  5th-6th       48.000000  41.000000  43.000000  35.000000  40.000000
#  7th-8th       31.000000  38.000000  50.444444  50.666667  40.857143
#  9th           26.640000  29.875000  32.666667  34.250000  38.500000
#  Assoc-acdm          NaN        NaN  50.000000  30.384615  27.047619
#  Assoc-voc           NaN        NaN  32.000000  34.500000  40.931034
#  Bachelors           NaN        NaN  35.000000  30.000000  31.428571
#  Doctorate           NaN        NaN        NaN        NaN        NaN
#  HS-grad       31.250000  29.269737  33.285714  36.350211  37.680000
# ...

# %%
adult2[adult2.17.notnull()]
# Out:
#   File "<ipython-input-130-3a729de4f24a>", line 1
#     adult2[adult2.17.notnull()]
#                    ^
# SyntaxError: invalid syntax
