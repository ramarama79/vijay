# %%
import pandas as pd

# %%
adult=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
adult
# Out:
#        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %%
adult.head
# Out:
# <bound method NDFrame.head of        39          State-gov   77516      Bachelors   13  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13
# 1      38            Private  215646        HS-grad    9
# 2      53            Private  234721           11th    7
# 3      28            Private  338409      Bachelors   13
# 4      37            Private  284582        Masters   14
# 5      49            Private  160187            9th    5
# 6      52   Self-emp-not-inc  209642        HS-grad    9
# 7      31            Private   45781        Masters   14
# 8      42            Private  159449      Bachelors   13
# 9      37            Private  280464   Some-college   10
# 10     30          State-gov  141297      Bachelors   13
# 11     23            Private  122272      Bachelors   13
# 12     32            Private  205019     Assoc-acdm   12
# 13     40            Private  121772      Assoc-voc   11
# 14     34            Private  245487        7th-8th    4
# ...

# %%
adult.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
adult.columns=['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-coutry', 'Income' ]

# %%
adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-coutry',
#        'Income'],
#       dtype='object')

# %%
adult1=pd.crosstab(adult.sex,adult.Income)

# %%
adult1
# Out:
# Income    <=50K   >50K
# sex
#  Female    9592   1179
#  Male     15127   6662

# %% [markdown]
#     male has higher generation income

# %%
adult1=pd.crosstab(adult.sex,adult.Income)
# Out:
# Income      <=50K      >50K
# sex
#  Female  0.890539  0.109461
#  Male    0.694249  0.305751

# %%
adult2=pd.crosstab(adult.race,adult.Income,normalize='index')

# %%
adult2
# Out:
# Income                  <=50K      >50K
# race
#  Amer-Indian-Eskimo  0.884244  0.115756
#  Asian-Pac-Islander  0.734360  0.265640
#  Black               0.876120  0.123880
#  Other               0.907749  0.092251
#  White               0.744131  0.255869

# %% [markdown]
# The other has least income of greater than 50000 as a propotion

# %%
adult3=pd.crosstab(adult.race,adult.education).apply(lambda r: r/r.sum())

# %%
adult3
# Out:
# education                10th      11th      12th   1st-4th   5th-6th  \
# race
#  Amer-Indian-Eskimo  0.017149  0.011915  0.011547  0.023810  0.006006
#  Asian-Pac-Islander  0.013934  0.017872  0.020785  0.029762  0.054054
#  Black               0.142551  0.130213  0.161663  0.095238  0.063063
#  Other               0.009646  0.008511  0.032333  0.053571  0.039039
#  White               0.816720  0.831489  0.773672  0.797619  0.837838
#
# education             7th-8th       9th   Assoc-acdm   Assoc-voc   Bachelors  \
# race
#  Amer-Indian-Eskimo  0.013932  0.009728     0.007498    0.013748    0.003922
#  Asian-Pac-Islander  0.017028  0.017510     0.027179    0.027496    0.053978
#  Black               0.086687  0.173152     0.100281    0.081042    0.061636
#  Other               0.026316  0.015564     0.007498    0.004342    0.006164
#  White               0.856037  0.784047     0.857545    0.873372    0.874300
#
# ...

# %% [markdown]
# the race AmerIndian eskimo has least education

# %%
adult4=pd.crosstab(adult.sex,adult.age).apply(lambda r: r/r.sum())

# %%
adult4
# Out:
# age            17        18   19        20        21        22       23  \
# sex
#  Female  0.470886  0.487273  0.5  0.482072  0.456944  0.447059  0.40935
#  Male    0.529114  0.512727  0.5  0.517928  0.543056  0.552941  0.59065
#
# age            24        25        26    ...           80    81        82  \
# sex                                      ...
#  Female  0.382206  0.372176  0.369427    ...     0.227273  0.45  0.166667
#  Male    0.617794  0.627824  0.630573    ...     0.772727  0.55  0.833333
#
# age            83   84        85   86   87        88        90
# sex
#  Female  0.166667  0.4  0.333333  1.0  0.0  0.333333  0.325581
#  Male    0.833333  0.6  0.666667  0.0  1.0  0.666667  0.674419
#
# [2 rows x 73 columns]

# %% [markdown]
# The male gender is older on a average

# %%
adult5=pd.crosstab(adult.education,adult.Income).apply(lambda r: r/r.sum())

# %%
adult5
# Out:
# Income            <=50K      >50K
# education
#  10th          0.035236  0.007907
#  11th          0.045107  0.007652
#  12th          0.016182  0.004209
#  1st-4th       0.006554  0.000765
#  5th-6th       0.012824  0.002041
#  7th-8th       0.024516  0.005101
#  9th           0.019701  0.003443
#  Assoc-acdm    0.032445  0.033797
#  Assoc-voc     0.041304  0.046040
#  Bachelors     0.126745  0.283255
#  Doctorate     0.004329  0.039026
#  HS-grad       0.357053  0.213621
#  Masters       0.030907  0.122306
#  Preschool     0.002063  0.000000
#  Prof-school   0.006190  0.053947
#  Some-college  0.238845  0.176891

# %%
Based on the education the income also changes
