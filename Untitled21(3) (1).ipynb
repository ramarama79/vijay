# %%
import os as os

# %%
import pandas as pd

# %%
# !pip install pyodbc

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin'

# %%
os.chdir('D:\\')

# %%
os.listdir()
# Out:
# ['$RECYCLE.BIN',
#  '.RData',
#  '.Rhistory',
#  '.Rproj.user',
#  '20170107_235933.jpg',
#  '20170107_235933.rar',
#  '94d5a5c4a69c5caf95883b7172',
#  'AlbumArtSmall.jpg',
#  'Arthashastra_of_Chanakya_-_English.pdf',
#  'aug sep.xlsx',
#  'AUGUST LULU 2016(5).xls',
#  'AXIS BANK MUTUAL FUND.pdf',
#  'axis bank statement.pdf',
#  'AxisMFOnline.pdf',
#  'BANGALORE TICKET brs..one',
#  'bank statement.pdf',
#  'BigDiamonds.csv',
#  'Book1.xlsx',
#  'bucon increment letter.pdf',
#  'bucon Septmber.xlsx',
#  'C.docx',
#  'CANCELLED CHEQUE.pdf',
#  'CANCELLED CHEQUE.txt',
#  'ccFraud.csv',
#  'ChatLog Data Analytics Course 2-introduction sas.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_09 21_38.rtf',
#  'cheque copy.pdf',
#  'connect to postgres',
#  'control panel.docx',
#  'copy formula.docx',
#  'Copy of Bucon- August 2016  latest(1).xlsx',
#  'Copy of Bucon- August 2016  latest.xlsx',
#  'Copy of Practice file after session 3.xlsx',
# ...

# %%
hedonic=pd.read_csv("Hedonic.csv")

# %%
hedonic2=hedonic

# %%
hedonic3=hedonic.copy()

# %%
type(hedonic)
# Out:
# pandas.core.frame.DataFrame

# %%
hedonic.columns
# Out:
# Index(['Unnamed: 0', 'mv', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age',
#        'dis', 'rad', 'tax', 'ptratio', 'blacks', 'lstat', 'townid'],
#       dtype='object')

# %%
hedonic.dtypes
# Out:
# Unnamed: 0      int64
# mv            float64
# crim          float64
# zn            float64
# indus         float64
# chas           object
# nox           float64
# rm            float64
# age           float64
# dis           float64
# rad           float64
# tax             int64
# ptratio       float64
# blacks        float64
# lstat         float64
# townid          int64
# dtype: object

# %%
hedonic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
# Unnamed: 0    506 non-null int64
# mv            506 non-null float64
# crim          506 non-null float64
# zn            506 non-null float64
# indus         506 non-null float64
# chas          506 non-null object
# nox           506 non-null float64
# rm            506 non-null float64
# age           506 non-null float64
# dis           506 non-null float64
# rad           506 non-null float64
# tax           506 non-null int64
# ptratio       506 non-null float64
# blacks        506 non-null float64
# lstat         506 non-null float64
# townid        506 non-null int64
# dtypes: float64(12), int64(3), object(1)
# memory usage: 63.3+ KB

# %%
hedonic.memory_usage()
# Out:
# Index           80
# Unnamed: 0    4048
# mv            4048
# crim          4048
# zn            4048
# indus         4048
# chas          4048
# nox           4048
# rm            4048
# age           4048
# dis           4048
# rad           4048
# tax           4048
# ptratio       4048
# blacks        4048
# lstat         4048
# townid        4048
# dtype: int64

# %%
hedonic.memory_usage(index=True).sum()
# Out:
# 64848

# %%
hedonic.shape
# Out:
# (506, 16)

# %%
len(hedonic)
# Out:
# 506

# %%
hedonic.columns
# Out:
# Index(['Unnamed: 0', 'mv', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age',
#        'dis', 'rad', 'tax', 'ptratio', 'blacks', 'lstat', 'townid'],
#       dtype='object')

# %%
hedonic.shape[1]
# Out:
# 16

# %%
len(hedonic)
# Out:
# 506

# %%
hedonic.head(10)
# Out:
#    Unnamed: 0        mv     crim    zn     indus chas        nox         rm  \
# 0           1  10.08580  0.00632  18.0  2.309999   no  28.944401  43.230598
# 1           2   9.98045  0.02731   0.0  7.070000   no  21.996099  41.229198
# 2           3  10.45450  0.02730   0.0  7.070000   no  21.996099  51.624199
# 3           4  10.41630  0.03237   0.0  2.179998   no  20.976400  48.972000
# 4           5  10.49680  0.06905   0.0  2.179998   no  20.976400  51.079601
# 5           6  10.26470  0.02985   0.0  2.179998   no  20.976400  41.344898
# 6           7  10.03890  0.08829  12.5  7.869999   no  27.457600  36.144100
# 7           8  10.20730  0.14455  12.5  7.869999   no  27.457600  38.093601
# 8           9   9.71112  0.21124  12.5  7.869999   no  27.457600  31.708200
# 9          10   9.84692  0.17004  12.5  7.869999   no  27.457600  36.048000
#
#           age      dis      rad  tax    ptratio   blacks    lstat  townid
# ...

# %%
hedonic.tail()
# Out:
#      Unnamed: 0        mv     crim   zn      indus chas        nox         rm  \
# 501         502  10.01680  0.06263  0.0  11.929993   no  32.832901  43.467701
# 502         503   9.93305  0.04527  0.0  11.929993   no  32.832901  37.454399
# 503         504  10.08160  0.06076  0.0  11.929993   no  32.832901  48.664600
# 504         505   9.99880  0.10959  0.0  11.929993   no  32.832901  46.158401
# 505         506   9.38429  0.04741  0.0  11.929993   no  32.832901  36.360901
#
#            age      dis  rad  tax  ptratio   blacks    lstat  townid
# 501  69.099976  0.90769  0.0  273     21.0  0.39199 -2.33604      92
# 502  76.699951  0.82746  0.0  273     21.0  0.39690 -2.39910      92
# 503  91.000000  0.77357  0.0  273     21.0  0.39690 -2.87582      92
# 504  89.299988  0.87083  0.0  273     21.0  0.39346 -2.73630      92
# 505  80.799988  0.91829  0.0  273     21.0  0.39690 -2.54033      92

# %%
hedonic.mv.head()
# Out:
# 0    10.08580
# 1     9.98045
# 2    10.45450
# 3    10.41630
# 4    10.49680
# Name: mv, dtype: float64

# %%
hedonic.head().mv
# Out:
# 0    10.08580
# 1     9.98045
# 2    10.45450
# 3    10.41630
# 4    10.49680
# Name: mv, dtype: float64

# %%
hedonic['mv'].head()
# Out:
# 0    10.08580
# 1     9.98045
# 2    10.45450
# 3    10.41630
# 4    10.49680
# Name: mv, dtype: float64

# %%
import numpy as np

# %%
hedonic[['mv','crim','zn']].head()
# Out:
#          mv     crim    zn
# 0  10.08580  0.00632  18.0
# 1   9.98045  0.02731   0.0
# 2  10.45450  0.02730   0.0
# 3  10.41630  0.03237   0.0
# 4  10.49680  0.06905   0.0

# %%
np.random.choice(100,5)
# Out:
# array([77, 39, 87, 75, 45])

# %%
np.random.choice(len(hedonic),0.000001*len(hedonic))
# Out:
# C:\Users\admin\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# array([], dtype=int32)

# %%
b=np.random.choice(len(hedonic),0.000001*len(hedonic))
# Out:
# C:\Users\admin\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':

# %%
hedonic.ix[b]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, mv, crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, blacks, lstat, townid]
# Index: []

# %%
del hedonic['mv']

# %%
hedonic
# Out:
#      Unnamed: 0      crim    zn      indus chas        nox         rm  \
# 0             1   0.00632  18.0   2.309999   no  28.944401  43.230598
# 1             2   0.02731   0.0   7.070000   no  21.996099  41.229198
# 2             3   0.02730   0.0   7.070000   no  21.996099  51.624199
# 3             4   0.03237   0.0   2.179998   no  20.976400  48.972000
# 4             5   0.06905   0.0   2.179998   no  20.976400  51.079601
# 5             6   0.02985   0.0   2.179998   no  20.976400  41.344898
# 6             7   0.08829  12.5   7.869999   no  27.457600  36.144100
# 7             8   0.14455  12.5   7.869999   no  27.457600  38.093601
# 8             9   0.21124  12.5   7.869999   no  27.457600  31.708200
# 9            10   0.17004  12.5   7.869999   no  27.457600  36.048000
# 10           11   0.22489  12.5   7.869999   no  27.457600  40.666100
# 11           12   0.11747  12.5   7.869999   no  27.457600  36.108101
# ...

# %%
hedonic.iloc[:,[1,2,3]]
# Out:
#          crim    zn      indus
# 0     0.00632  18.0   2.309999
# 1     0.02731   0.0   7.070000
# 2     0.02730   0.0   7.070000
# 3     0.03237   0.0   2.179998
# 4     0.06905   0.0   2.179998
# 5     0.02985   0.0   2.179998
# 6     0.08829  12.5   7.869999
# 7     0.14455  12.5   7.869999
# 8     0.21124  12.5   7.869999
# 9     0.17004  12.5   7.869999
# 10    0.22489  12.5   7.869999
# 11    0.11747  12.5   7.869999
# 12    0.09378  12.5   7.869999
# 13    0.62976   0.0   8.139999
# 14    0.63796   0.0   8.139999
# 15    0.62739   0.0   8.139999
# 16    1.05393   0.0   8.139999
# 17    0.78420   0.0   8.139999
# 18    0.80271   0.0   8.139999
# 19    0.72580   0.0   8.139999
# 20    1.25179   0.0   8.139999
# 21    0.85204   0.0   8.139999
# 22    1.23247   0.0   8.139999
# 23    0.98843   0.0   8.139999
# 24    0.75026   0.0   8.139999
# 25    0.84054   0.0   8.139999
# 26    0.67191   0.0   8.139999
# 27    0.95578   0.0   8.139999
# 28    0.77299   0.0   8.139999
# ...

# %% [markdown]
# fraud.iloc[:,[1,2,8]].head()

# %% [markdown]
# fraud.drop(fraud.columns[[0, 4]], axis=1, inplace=True)

# %%
hedonic.drop(hedonic.columns[[0,4]],axis=1,inplace=True)

# %%
hedonic.head()
# Out:
#       crim    zn     indus        nox         rm        age      dis      rad  \
# 0  0.00632  18.0  2.309999  28.944401  43.230598  65.199951  1.40854  0.00000
# 1  0.02731   0.0  7.070000  21.996099  41.229198  78.899963  1.60283  0.69315
# 2  0.02730   0.0  7.070000  21.996099  51.624199  61.099976  1.60283  0.69315
# 3  0.03237   0.0  2.179998  20.976400  48.972000  45.799988  1.80207  1.09861
# 4  0.06905   0.0  2.179998  20.976400  51.079601  54.199982  1.80207  1.09861
#
#    tax    ptratio   blacks    lstat  townid
# 0  296  15.299995  0.39690 -3.00074       1
# 1  242  17.799988  0.39690 -2.39251       2
# 2  242  17.799988  0.39283 -3.21165       2
# 3  222  18.699997  0.39464 -3.52744       3
# 4  222  18.699997  0.39690 -2.93163       3

# %%
hedonic2.head()
# Out:
#       crim    zn     indus        nox         rm        age      dis      rad  \
# 0  0.00632  18.0  2.309999  28.944401  43.230598  65.199951  1.40854  0.00000
# 1  0.02731   0.0  7.070000  21.996099  41.229198  78.899963  1.60283  0.69315
# 2  0.02730   0.0  7.070000  21.996099  51.624199  61.099976  1.60283  0.69315
# 3  0.03237   0.0  2.179998  20.976400  48.972000  45.799988  1.80207  1.09861
# 4  0.06905   0.0  2.179998  20.976400  51.079601  54.199982  1.80207  1.09861
#
#    tax    ptratio   blacks    lstat  townid
# 0  296  15.299995  0.39690 -3.00074       1
# 1  242  17.799988  0.39690 -2.39251       2
# 2  242  17.799988  0.39283 -3.21165       2
# 3  222  18.699997  0.39464 -3.52744       3
# 4  222  18.699997  0.39690 -2.93163       3

# %%
hedonic3.head()
# Out:
#    Unnamed: 0        mv     crim    zn     indus chas        nox         rm  \
# 0           1  10.08580  0.00632  18.0  2.309999   no  28.944401  43.230598
# 1           2   9.98045  0.02731   0.0  7.070000   no  21.996099  41.229198
# 2           3  10.45450  0.02730   0.0  7.070000   no  21.996099  51.624199
# 3           4  10.41630  0.03237   0.0  2.179998   no  20.976400  48.972000
# 4           5  10.49680  0.06905   0.0  2.179998   no  20.976400  51.079601
#
#          age      dis      rad  tax    ptratio   blacks    lstat  townid
# 0  65.199951  1.40854  0.00000  296  15.299995  0.39690 -3.00074       1
# 1  78.899963  1.60283  0.69315  242  17.799988  0.39690 -2.39251       2
# 2  61.099976  1.60283  0.69315  242  17.799988  0.39283 -3.21165       2
# 3  45.799988  1.80207  1.09861  222  18.699997  0.39464 -3.52744       3
# 4  54.199982  1.80207  1.09861  222  18.699997  0.39690 -2.93163       3

# %%
hedonic3.shape
# Out:
# (506, 16)

# %%
hedonic.drop(hedonic.index[[0,1,2,3]])
# Out:
#          crim    zn      indus        nox         rm         age      dis  \
# 4     0.06905   0.0   2.179998  20.976400  51.079601   54.199982  1.80207
# 5     0.02985   0.0   2.179998  20.976400  41.344898   58.699982  1.80207
# 6     0.08829  12.5   7.869999  27.457600  36.144100   66.599976  1.71569
# 7     0.14455  12.5   7.869999  27.457600  38.093601   96.099976  1.78347
# 8     0.21124  12.5   7.869999  27.457600  31.708200  100.000000  1.80535
# 9     0.17004  12.5   7.869999  27.457600  36.048000   85.899963  1.88587
# 10    0.22489  12.5   7.869999  27.457600  40.666100   94.299988  1.84793
# 11    0.11747  12.5   7.869999  27.457600  36.108101   82.899963  1.82885
# 12    0.09378  12.5   7.869999  27.457600  34.680302   39.000000  1.69578
# 13    0.62976   0.0   8.139999  28.944401  35.390598   61.799988  1.54916
# 14    0.63796   0.0   8.139999  28.944401  37.161201   84.500000  1.49557
# 15    0.62739   0.0   8.139999  28.944401  34.035500   56.500000  1.50377
# ...

# %%
s=pd.Series(range(1,101))

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
hedonic3.iloc[20:30,[1,8,11]]
# Out:
#          mv         age  tax
# 20  9.51783   98.099976  307
# 21  9.88329   89.199951  307
# 22  9.62905   91.699951  307
# 23  9.58190  100.000000  307
# 24  9.65503   94.099976  307
# 25  9.53964   85.699951  307
# 26  9.71716   90.299988  307
# 27  9.60238   88.799988  307
# 28  9.82011   94.399963  307
# 29  9.95228   87.299988  307

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Downloads'

# %%
os.listdir('D:\\')
# Out:
# ['$RECYCLE.BIN',
#  '.RData',
#  '.Rhistory',
#  '.Rproj.user',
#  '20170107_235933.jpg',
#  '20170107_235933.rar',
#  '94d5a5c4a69c5caf95883b7172',
#  'AlbumArtSmall.jpg',
#  'Arthashastra_of_Chanakya_-_English.pdf',
#  'aug sep.xlsx',
#  'AUGUST LULU 2016(5).xls',
#  'AXIS BANK MUTUAL FUND.pdf',
#  'axis bank statement.pdf',
#  'AxisMFOnline.pdf',
#  'BANGALORE TICKET brs..one',
#  'bank statement.pdf',
#  'BigDiamonds.csv',
#  'Book1.xlsx',
#  'bucon increment letter.pdf',
#  'bucon Septmber.xlsx',
#  'C.docx',
#  'CANCELLED CHEQUE.pdf',
#  'CANCELLED CHEQUE.txt',
#  'ccFraud.csv',
#  'ChatLog Data Analytics Course 2-introduction sas.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_09 21_38.rtf',
#  'cheque copy.pdf',
#  'connect to postgres',
#  'control panel.docx',
#  'copy formula.docx',
#  'Copy of Bucon- August 2016  latest(1).xlsx',
#  'Copy of Bucon- August 2016  latest.xlsx',
#  'Copy of Practice file after session 3.xlsx',
# ...

# %%
os.listdir('D:\\')
# Out:
# ['$RECYCLE.BIN',
#  '.RData',
#  '.Rhistory',
#  '.Rproj.user',
#  '20170107_235933.jpg',
#  '20170107_235933.rar',
#  '94d5a5c4a69c5caf95883b7172',
#  'AlbumArtSmall.jpg',
#  'Arthashastra_of_Chanakya_-_English.pdf',
#  'aug sep.xlsx',
#  'AUGUST LULU 2016(5).xls',
#  'AXIS BANK MUTUAL FUND.pdf',
#  'axis bank statement.pdf',
#  'AxisMFOnline.pdf',
#  'BANGALORE TICKET brs..one',
#  'bank statement.pdf',
#  'BigDiamonds.csv',
#  'Book1.xlsx',
#  'bucon increment letter.pdf',
#  'bucon Septmber.xlsx',
#  'C.docx',
#  'CANCELLED CHEQUE.pdf',
#  'CANCELLED CHEQUE.txt',
#  'ccFraud.csv',
#  'ChatLog Data Analytics Course 2-introduction sas.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_09 21_38.rtf',
#  'cheque copy.pdf',
#  'connect to postgres',
#  'control panel.docx',
#  'copy formula.docx',
#  'Copy of Bucon- August 2016  latest(1).xlsx',
#  'Copy of Bucon- August 2016  latest.xlsx',
#  'Copy of Practice file after session 3.xlsx',
# ...

# %%
fraud=pd.read_csv("ccFraud.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-153-f8109c2049e3> in <module>()
# ----> 1 fraud=pd.read_csv("ccFraud.csv")
#
# C:\Users\admin\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
fraud2=fraud

# %%
fraud3=fraud.copy()

# %%
fraud.head()
# Out:
#    state  balance  creditLine  fraudRisk
# 0     35     3000           2          0
# 1      2        0          18          0
# 2      2        0          16          0
# 3     15        0           5          0
# 4     46        0           7          0

# %%
fraud.tail()
# Out:
#          state  cardholder  balance  numTrans  numIntlTrans  creditLine  \
# 9999995     37           1        0        10             0           9
# 9999996     16           1        0        33             2           4
# 9999997     24           1     9000        38             0           8
# 9999998     28           1     7000        20            19           6
# 9999999     23           1        0        13             0           7
#
#          fraudRisk
# 9999995          0
# 9999996          0
# 9999997          0
# 9999998          0
# 9999999          0

# %%
fraud.columns
# Out:
# Index(['state', 'cardholder', 'balance', 'numTrans', 'numIntlTrans',
#        'creditLine', 'fraudRisk'],
#       dtype='object')

# %%
fraud.dtypes
# Out:
# state           int64
# cardholder      int64
# balance         int64
# numTrans        int64
# numIntlTrans    int64
# creditLine      int64
# fraudRisk       int64
# dtype: object

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 7 columns):
# state           int64
# cardholder      int64
# balance         int64
# numTrans        int64
# numIntlTrans    int64
# creditLine      int64
# fraudRisk       int64
# dtypes: int64(7)
# memory usage: 534.1 MB

# %%
fraud.memory_usage()
# Out:
# Index                 80
# state           80000000
# cardholder      80000000
# balance         80000000
# numTrans        80000000
# numIntlTrans    80000000
# creditLine      80000000
# fraudRisk       80000000
# dtype: int64

# %%
fraud.memory_usage(index=True).sum()
# Out:
# 560000080

# %%
fraud.shape
# Out:
# (10000000, 7)

# %% [markdown]
# del fraud['custID']

# %%
fraud.head()

# %%
fraud.state.head()
# Out:
# 0    35
# 1     2
# 2     2
# 3    15
# 4    46
# Name: state, dtype: int64

# %%
fraud.head().state
# Out:
# 0    35
# 1     2
# 2     2
# 3    15
# 4    46
# Name: state, dtype: int64

# %%
fraud['state'].head()
# Out:
# 0    35
# 1     2
# 2     2
# 3    15
# 4    46
# Name: state, dtype: int64

# %%
fraud[['state','cardholder','balance']]
# Out:
#          state  cardholder  balance
# 0           35           1     3000
# 1            2           1        0
# 2            2           1        0
# 3           15           1        0
# 4           46           1        0
# 5           44           2     5546
# 6            3           1     2000
# 7           10           1     6016
# 8           32           1     2428
# 9           23           1        0
# 10          46           1     4601
# 11          10           1     3000
# 12           6           1        0
# 13          38           1     9000
# 14          27           1     5227
# 15          44           1        0
# 16          18           1    13970
# 17          35           1     3113
# 18           5           1     9000
# 19          31           1     1860
# 20          39           1     4000
# 21          34           1        0
# 22           5           1        0
# 23          21           1        0
# 24          25           1        0
# ...

# %%
import numpy as np

# %%
np.random.choice(len(fraud),.000001*len(fraud))
# Out:
# C:\Users\admin\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# array([6918675, 7830339, 9999246, 6908195, 5177429, 4818925, 9862515,
#        5157045, 7087464, 3827710])

# %%
b=np.random.choice(len(fraud),.000001*len(fraud))
# Out:
# C:\Users\admin\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':

# %%
b
# Out:
# array([9138423, 5765575,   48942, 7121765, 4114050, 1362367, 4710542,
#        5325423, 3489582, 6397735])

# %%
fraud.iloc[b]
# Out:
#          state  cardholder  balance  numTrans  numIntlTrans  creditLine  \
# 9138423     36           1     6000        28             9           5
# 5765575     36           1     5059         9             9           9
# 48942       48           1     2690         4             0           8
# 7121765     30           1     5954        33             0           9
# 4114050     46           1      969        41             2          19
# 1362367     35           1     9656        14            10          14
# 4710542      7           2        0        44             7           2
# 5325423     35           1    10000        10             0           9
# 3489582      5           1     5000        84             9           4
# 6397735     29           1     4000         8             9           3
#
#          fraudRisk
# 9138423          0
# 5765575          0
# 48942            0
# 7121765          0
# 4114050          0
# 1362367          0
# 4710542          0
# ...

# %%
fraud.drop(fraud.columns[[1,3,4]],axis=1,inplace=True)

# %%
fraud.head()
# Out:
#    state  balance  creditLine  fraudRisk
# 0     35     3000           2          0
# 1      2        0          18          0
# 2      2        0          16          0
# 3     15        0           5          0
# 4     46        0           7          0

# %%
fraud.drop(fraud.index[[0,1,3]])
# Out:
#          state  balance  creditLine  fraudRisk
# 2            2        0          16          0
# 4           46        0           7          0
# 5           44     5546          13          0
# 6            3     2000           1          0
# 7           10     6016           6          0
# 8           32     2428          22          0
# 9           23        0           5          0
# 10          46     4601           4          0
# 11          10     3000           2          0
# 12           6        0           4          0
# 13          38     9000           8          0
# 14          27     5227          17          0
# 15          44        0           5          0
# 16          18    13970          13          0
# 17          35     3113           8          0
# 18           5     9000           8          0
# 19          31     1860           8          0
# 20          39     4000           3          0
# 21          34        0           3          0
# ...

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.chdir('C:/Users/admin/Downloads')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01PrayersAndMeditations.pdf',
#  '11.pdf',
#  'AirPassengers.csv',
#  'AKAKRECPTS2015 - Copy of Sheet1.csv',
#  'Anaconda3-4.3.0.1-Windows-x86_64 (1).exe',
#  'Anaconda3-4.3.0.1-Windows-x86_64.exe',
#  'BigDiamonds.csv',
#  'BigDiamonds.csv (1).zip',
#  'BigDiamonds.csv.zip',
#  'BigDiamonds.csv.zip (Unzipped Files)-20170228T145348Z-001',
#  'BigDiamonds.csv.zip (Unzipped Files)-20170228T145348Z-001.zip',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_07 16_17 (1).rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_07 16_17 (2).rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_07 16_17.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_09 21_38.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_14 21_35.rtf',
#  'ChatLog Data Analytics Course Weekday Batch  2017_02_16 21_34.rtf',
#  'ChatLog Data Analytics Weekday Batch 2017_03_16 21_35.rtf',
# ...

# %%
mortage=pd.read_csv("mortDefault2009.csv")

# %%
mortage.head()
# Out:
#    creditScore  houseAge  yearsEmploy  ccDebt  year  default
# 0          617        20            8    4410  2009        0
# 1          623        11            7    5609  2009        0
# 2          758        17            4    7250  2009        0
# 3          687        22            5    3761  2009        0
# 4          663        15            6    6746  2009        0

# %%
len(mortage)
# Out:
# 1000000

# %%
mortage1=mortage

# %%
mortage2=mortage.copy()

# %%
mortage.houseAge.head()
# Out:
# 0    20
# 1    11
# 2    17
# 3    22
# 4    15
# Name: houseAge, dtype: int64

# %%
mortage.head().houseAge
# Out:
# 0    20
# 1    11
# 2    17
# 3    22
# 4    15
# Name: houseAge, dtype: int64

# %%
md=mortage[['houseAge','ccDebt']]

# %%
md
# Out:
#         houseAge  ccDebt
# 0             20    4410
# 1             11    5609
# 2             17    7250
# 3             22    3761
# 4             15    6746
# 5             10    7106
# 6             23    2280
# 7             18    2831
# 8              9    3867
# 9             16    6238
# 10            30    4109
# 11            19    4122
# 12            25    4235
# 13            27    4456
# 14            21    4723
# 15            16    5220
# 16            21    3194
# 17            15    4750
# 18            34    3478
# 19            11    3181
# 20            26    5467
# 21            17    2744
# 22            14    3969
# 23            24     331
# 24            27    7178
# 25            25    4752
# 26            20    8419
# 27            17    2500
# 28            14    5676
# 29            15    2654
# ...          ...     ...
# 999970        18    1268
# 999971        17    3968
# 999972        19    8994
# 999973        17    8810
# 999974        21    6149
# ...

# %%
md.debtperhousehold=md.ccDebt/md.houseAge

# %%
md.columns
# Out:
# Index(['houseAge', 'ccDebt'], dtype='object')

# %%
md.columns=(['houseAge', 'ccDebt','debtperhousehold'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-cf404a713a27> in <module>()
# ----> 1 md.columns=(['houseAge', 'ccDebt','debtperhousehold'])
#
# C:\Users\admin\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    2755         try:
#    2756             object.__getattribute__(self, name)
# -> 2757             return object.__setattr__(self, name, value)
#    2758         except AttributeError:
#    2759             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:46249)()
#
# C:\Users\admin\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     446
#     447     def _set_axis(self, axis, labels):
# --> 448         self._data.set_axis(axis, labels)
#     449         self._clear_item_cache()
#     450
#
# ...

# %%
md
# Out:
#         houseAge  ccDebt
# 0             20    4410
# 1             11    5609
# 2             17    7250
# 3             22    3761
# 4             15    6746
# 5             10    7106
# 6             23    2280
# 7             18    2831
# 8              9    3867
# 9             16    6238
# 10            30    4109
# 11            19    4122
# 12            25    4235
# 13            27    4456
# 14            21    4723
# 15            16    5220
# 16            21    3194
# 17            15    4750
# 18            34    3478
# 19            11    3181
# 20            26    5467
# 21            17    2744
# 22            14    3969
# 23            24     331
# 24            27    7178
# 25            25    4752
# 26            20    8419
# 27            17    2500
# 28            14    5676
# 29            15    2654
# ...          ...     ...
# 999970        18    1268
# 999971        17    3968
# 999972        19    8994
# 999973        17    8810
# 999974        21    6149
# ...

# %%
mortage.drop(mortage.columns[[0,5]],axis=1,inplace=True)

# %%
mortage.head()
# Out:
#    houseAge  yearsEmploy  ccDebt  year
# 0        20            8    4410  2009
# 1        11            7    5609  2009
# 2        17            4    7250  2009
# 3        22            5    3761  2009
# 4        15            6    6746  2009

# %%
mortage.drop(mortage.index[[0,1,3]])
# Out:
#         houseAge  yearsEmploy  ccDebt  year
# 2             17            4    7250  2009
# 4             15            6    6746  2009
# 5             10            2    7106  2009
# 6             23            2    2280  2009
# 7             18            7    2831  2009
# 8              9            5    3867  2009
# 9             16            8    6238  2009
# 10            30            6    4109  2009
# 11            19            6    4122  2009
# 12            25            4    4235  2009
# 13            27            1    4456  2009
# 14            21            7    4723  2009
# 15            16            5    5220  2009
# 16            21            3    3194  2009
# 17            15            8    4750  2009
# 18            34            6    3478  2009
# 19            11            7    3181  2009
# 20            26            6    5467  2009
# 21            17            2    2744  2009
# 22            14            5    3969  2009
# ...

# %%
mortage=np.choice.random(len(mortage),.000001*len(mortage))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-a8e8d56fb4b6> in <module>()
# ----> 1 mortage=np.choice.random(len(mortage),.000001*len(mortage))
#
# AttributeError: module 'numpy' has no attribute 'choice'

# %%
ab=np.random.choice(len(mortage),.000001*len(mortage))
# Out:
# C:\Users\admin\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':

# %%
mortage.iloc[ab]
# Out:
#         houseAge  yearsEmploy  ccDebt  year
# 780175        25            6    2850  2009
